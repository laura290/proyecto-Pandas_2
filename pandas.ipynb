# %%
import pandas as pd

# %%
df = pd.read_csv("input/attacks.csv",encoding='ISO-8859-1')

# %%
df
# Out:
#       Case Number         Date    Year        Type    Country  \
# 0      2018.06.25  25-Jun-2018  2018.0     Boating        USA
# 1      2018.06.18  18-Jun-2018  2018.0  Unprovoked        USA
# 2      2018.06.09  09-Jun-2018  2018.0     Invalid        USA
# 3      2018.06.08  08-Jun-2018  2018.0  Unprovoked  AUSTRALIA
# 4      2018.06.04  04-Jun-2018  2018.0    Provoked     MEXICO
# ...           ...          ...     ...         ...        ...
# 25718         NaN          NaN     NaN         NaN        NaN
# 25719         NaN          NaN     NaN         NaN        NaN
# 25720         NaN          NaN     NaN         NaN        NaN
# 25721         NaN          NaN     NaN         NaN        NaN
# 25722          xx          NaN     NaN         NaN        NaN
#
#                   Area                        Location     Activity  \
# 0           California     Oceanside, San Diego County     Paddling
# 1              Georgia  St. Simon Island, Glynn County     Standing
# ...

# %%
df.columns
# Out:
# Index(['Case Number', 'Date', 'Year', 'Type', 'Country', 'Area', 'Location',
#        'Activity', 'Name', 'Sex ', 'Age', 'Injury', 'Fatal (Y/N)', 'Time',
#        'Species ', 'Investigator or Source', 'pdf', 'href formula', 'href',
#        'Case Number.1', 'Case Number.2', 'original order', 'Unnamed: 22',
#        'Unnamed: 23'],
#       dtype='object')

# %%
df.isnull().any()
# Out:
# Case Number               True
# Date                      True
# Year                      True
# Type                      True
# Country                   True
# Area                      True
# Location                  True
# Activity                  True
# Name                      True
# Sex                       True
# Age                       True
# Injury                    True
# Fatal (Y/N)               True
# Time                      True
# Species                   True
# Investigator or Source    True
# pdf                       True
# href formula              True
# href                      True
# Case Number.1             True
# Case Number.2             True
# original order            True
# Unnamed: 22               True
# Unnamed: 23               True
# dtype: bool

# %%
df.Country.isnull().value_counts()
# Out:
# False    5711
# Name: Country, dtype: int64

# %%
df.drop(df[df.Country.isnull()].index, inplace = True)

# %%
df.Country.isnull().sum()
# Out:
# 0

# %%
df.Activity.isnull().value_counts()
# Out:
# False    5711
# Name: Activity, dtype: int64

# %%
df.drop(df[df.Activity.isnull()].index, inplace = True)

# %%
df.Activity.isnull().sum()
# Out:
# 0

# %%
df.Injury.isnull().value_counts()
# Out:
# False    5696
# True       15
# Name: Injury, dtype: int64

# %%
Injury =attack.drop(attack[attack.Injury.isnull()].index, inplace = True)

# %%
attack.Injury.isnull().sum()
# Out:
# 0

# %%
d =df[["Country","Activity","Injury"]]
display(d)
# Out:
#                  Country      Activity  \
# 0                    USA      Paddling
# 1                    USA      Standing
# 2                    USA       Surfing
# 3              AUSTRALIA       Surfing
# 4                 MEXICO   Free diving
# ...                  ...           ...
# 6296           AUSTRALIA      Swimming
# 6297           AUSTRALIA        Diving
# 6298           AUSTRALIA  Pearl diving
# 6299                 USA      Swimming
# 6301  CEYLON (SRI LANKA)      Swimming
#
#                                                  Injury
# 0                                             No injury
# 1                            Minor injury to left thigh
# 2          Injury to left lower leg from surfboard skeg
# 3                             Minor injury to lower leg
# 4     Lacerations to leg & hand shark PROVOKED INCIDENT
# ...                                                 ...
# 6296                                              FATAL
# ...

# %%
df["Activity"].value_counts()
# Out:
# Surfing                                                                                                        969
# Swimming                                                                                                       862
# Fishing                                                                                                        430
# Spearfishing                                                                                                   332
# Bathing                                                                                                        160
#                                                                                                               ...
# Fishing for rock lobsters                                                                                        1
# Scuba diving, but swimming on surface                                                                            1
# ...

# %%
df_Injury = df.Injury.str.replace(r"(.*)No injury(.*)",'No injury')

# %%
df_Injury = df.Injury.str.replace(r"(.*)Minor injury(.*)",'Minor injury')

# %%
df_Injury = df.Injury.str.replace(r"(.*)Injury(.*)",'Injury')

# %%
df_Injury = df.Injury.str.replace(r"(.*)Legs|legs(.*)",'Injury')

# %%
df_Injury = df.Injury.str.replace(r"(.*)Arms|arm(.*)",'Injury')

# %%
df_Injury = df.Injury.str.replace(r"(.*)FATAL(.*)",'FATAL')

# %%
df.Injury = df.Injury.str.replace(r"(.*) injuries|Injuries(.*)",'Injury')

# %%
a= df[["Activity","Injury"]][df["Activity"]=="Surfing"]
b= df[["Activity","Injury"]][df["Activity"]=="Swimming"]
c= df[["Activity","Injury"]][df["Activity"]=="fishing"]
display(a,b,c)
# Out:
#      Activity                                             Injury
# 2     Surfing       Injury to left lower leg from surfboard skeg
# 3     Surfing                          Minor injury to lower leg
# 15    Surfing                       Minor injury, marks on board
# 16    Surfing                                          No injury
# 19    Surfing                                          No injury
# ...       ...                                                ...
# 5235  Surfing  FATAL, disappeared, then his shark-bitten rema...
# 5280  Surfing  Severe laceration to arm, necessitating surgic...
# 6097  Surfing                                              FATAL
# 6143  Surfing                         FATAL, buttock lacerated
# 6201  Surfing                                        Legs bitten
#
# [969 rows x 2 columns]
#       Activity                                             Injury
# 6     Swimming                                              FATAL
# ...

# %%
df["Injury"].value_counts()
# Out:
# No injury                                                                                 708
# FATAL                                                                                     703
# Foot bitten                                                                                84
# Leg bitten                                                                                 67
# Survived                                                                                   54
#                                                                                          ...
# FATAL, disappeared, partial remains of Selim was found, there was no trace of Dea Opre      1
# FATAL, left thigh bitten                                                                    1
# FATAL, shark involvement prior to death is unconfirmed                                      1
# Next day 2 bodies recovered from sharks                                                     1
# ...

# %%
d.groupby(['Country','Activity'])[['Injury']].count()
# Out:
#                                                                  Injury
# Country      Activity
#  PHILIPPINES USS Hoel DD 533 sunk on 10/24/1944 in the Battl...       1
#  TONGA       Five men on makeshift raft after their 10 m fis...       2
#              Scuba diving                                             1
# AFRICA       Jumped into river                                        1
# ALGERIA      Swimming                                                 1
# ...                                                                 ...
# YEMEN        Diving around anchored liner                             1
#              Diving for coins                                         2
#              Standing                                                 1
#              Swimming at side of small boat                           1
#              Wreck of the steamship Sultan of Bombay                  1
#
# [2171 rows x 1 columns]
